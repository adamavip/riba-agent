# %% [markdown]
# Packages

# %%
import joblib
import os

# %% [markdown]
# Load the model

# %%
BASE_DIR = os.path.dirname(os.path.abspath(__file__))
MODEL_PATH = os.path.join(BASE_DIR, "SSA_maize_yield_response", "gbm_yield_model.joblib")
model = joblib.load(MODEL_PATH)
